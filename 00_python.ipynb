# %% [markdown]
# this entire notebook is done by me to give deeper understanding of concepts of python.

# %% [markdown]
# Types, String Operations, Expression and Variables , Lists, Tuples, Dictionaries,Sets,Conditions and Branching,
#
# Loops, Functions , Exception Handling, Objects and Classes, Reading Files with Open , Writing Files with Open , Loading Data with Pandas
#  One Dimensional Numpy, Two Dimensional Numpy

# %% [markdown]
# Python is a popular programming language. It was created by Guido van Rossum, and released in 1991.
# python is object-oriented,interpeter and scripting language.

# %% [markdown]
# | Aspect          | Compiler                           | Interpreter                                         |
# | --------------- | ---------------------------------- | --------------------------------------------------- |
# | Processing      | Entire program at once             | Line by line builtin+1​                             |
# | Speed           | Faster execution after compilation | Slower due to runtime translation tutorialspoint+1​ |
# | Error Detection | All errors shown after full scan   | Errors shown per line builtin+1​                    |
# | Output          | Generates machine code file (.exe) | No intermediate file needed tutorialspoint​         |
# | Memory Use      | Higher during compilation          | Lower, runs directly byjus​                         |

# %% [markdown]
# integter, boolean,float,string,Tuples,list,Dictionary,sets, array are most used data structure in python

# %%
type(1) # integer are digits positive or negative digits.
# Out:
# int

# %%
type(1.2) # float is decimal vaule numeric
# Out:
# float

# %%
type(True)  #boolean is true or false in binary format
# Out:
# bool

# %%
type("helo world") # string is alphanumeric represents with "" or ''.
# Out:
# str

# %%
#type casting is changing one data type to other data type. int to float
float(1)
# Out:
# 1.0

# %%
int("1") #string to int
# Out:
# 1

# %%
int(1.5) # float to int
# Out:
# 1

# %%
bool(1.5) # float to boolean
# Out:
# True

# %%
bool(3) #int to boolean
# Out:
# True

# %%
type(6//3)
# Out:
# int

# %%
type("hello" == "world")
# Out:
# bool
