# %%
Strings in python are surrounded by either single quotation marks, or double quotation marks.

# %% [markdown]
# The standards for ASCII A-Z as decimal values 65-90 and lowercase a-z as 97-122.

# %%
a = "Hello"
print(a)
# Out:
# Hello

# %%
s = "Hello"
print(len(s))
# Out:
# 5

# %%
a = """The day , where the leaf felt cold outside is autum season and the leaf fall down then it is called as deciduas tree ."""
print(a) # multiple lines """ """ three qutoes
# Out:
# The day , where the leaf felt cold outside is autum season and the leaf fall down then it is called as deciduas tree .

# %%
a="Hello world" # Indexing
a[1]
# Out:
# 'e'

# %%
a.split()
# Out:
# ['The',
#  'day',
#  ',',
#  'where',
#  'the',
#  'leaf',
#  'felt',
#  'cold',
#  'outside',
#  'is',
#  'autum',
#  'season',
#  'and',
#  'the',
#  'leaf',
#  'fall',
#  'down',
#  'then',
#  'it',
#  'is',
#  'called',
#  'as',
#  'deciduas',
#  'tree',
#  '.']

# %%
a.replace("e","b")
# Out:
# 'Thb day , whbrb thb lbaf fblt cold outsidb is autum sbason and thb lbaf fall down thbn it is callbd as dbciduas trbb .'

# %%
Slicing:the start index and the end index, separated by a colon, to return a part of the string.

# %%
b = "Hello, World!"
print(b[2:5])
# Out:
# llo

# %%
b = "Hello, World!"
print(b[-5:-2])
# Out:
# orl

# %%
#The upper() method returns the string in upper case
a = "Hello, World!"
print(a.upper())
# Out:
# HELLO, WORLD!

# %%
a = "Hello, World!"
print(a.lower())
# Out:
# hello, world!

# %%
a = " Hello, World! "
print(a.strip()) # returns "Hello, World!" and remove extra white space
# Out:
# Hello, World!

# %%
a = "Hello"
b = "World"
c = a + b
print(c)
# Out:
# HelloWorld

# %%
a = "Hello"
b = "World"
c = a + " " + b
print(c)
# Out:
# Hello World

# %%
a="Hello world"
a.find("o")
# Out:
# 4

# %%
x, y, z = "Orange", "Banana", "Cherry"
print(x)
print(y)
print(z)
# Out:
# Orange
# Banana
# Cherry
