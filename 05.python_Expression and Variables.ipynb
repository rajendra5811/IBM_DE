# %% [markdown]
# A variable name must start with a letter or the underscore character
# A variable name cannot start with a number
# A variable name can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ )
# Variable names are case-sensitive (age, Age and AGE are three different variables)
# A variable name cannot be any of the Python keywords.

# %%
import keyword
print("The list of keywords are : ")
print(keyword.kwlist) #1
# Out:
# The list of keywords are :
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
var and = 1;
print(and) # no keywords
# Out:
#   Cell In[13], line 1
#     var and = 1;
#             ^
# SyntaxError: invalid syntax

# %%
var Ant=5;
var 9NT=1;
print(Ant,9ANT); #cannot start with number3
# Out:
#   Cell In[20], line 2
#     var 9NT=1;
#         ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# one value assign to multiple variables

# %%
x=y=z="good"
print(x)
print(y)  #4
print(z)
# Out:
# good
# good
# good

# %% [markdown]
# BODMAS {[( division multiplication addition subtraction

# %%
a,b =15,16;
print(a+b);
print(a-b);  #5
print(a*b);
print(a/b);
print(a//b); 
print(a^b);
print(a*b+a/b+a); # first division , mul(a,b), addition ( arithmatic operator)
# Out:
# 31
# -1
# 240
# 0.9375
# 0
# 31
# 255.9375

# %%
a,b =5,10;
print(a>b);
print(a<b);
print(a==b);
print(a!=b);
print(a>=b);
print(a<=b); #comparision operator
# Out:
# False
# True
# False
# True
# False
# True

# %%
a,b=6,8;
print(a and b);
print(a or b);
print(not a);  #logical operator
# Out:
# 8
# 6
# False

# %%
a,b=9,4;
print(a&b);
print(a|b);
print(~a);
print(a^b);
print(a>>2);
print(a<<2); #BITWISE operator
# Out:
# 0
# 13
# -10
# 13
# 2
# 36

# %%
a,b=9,4;
b+=a;
print(b);
b-=a;
print(b);
b*=a;
print(b);
b<<=a;
print(b); #assignment operator
# Out:
# 13
# 4
# 36
# 18432

# %%
a,b=8,5;
print(a is not b);
print(a is b); #identity operator
# Out:
# True
# False

# %%
a,b=8,6;
m=a if a < b else b;
print(m)
# Out:
# 6
